# %% [markdown]
# <a href="https://colab.research.google.com/github/XtremeCmd/sql-ecommerce-analysis/blob/main/sales_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (8, 5)

# %%
df = pd.read_csv("/content/total_revenue.csv")
df
# Out:
#    total_revenue
# 0        70996.5

# %% [markdown]
# The total revenue represents the overall scale of business activity during the analyzed period and provides a baseline for comparing performance across products, customers, and time.

# %%
df_total = pd.read_csv("/content/total_revenue.csv")

total_revenue = df_total.iloc[0, 0]
print(f"Total Revenue: {total_revenue}")
# Out:
# Total Revenue: 70996.5

# %%
df_monthly = pd.read_csv("/content/monthly_revenue.csv")

plt.figure()
plt.plot(df_monthly["month"], df_monthly["monthly_revenue"], marker="o")
plt.title("Monthly Revenue Trend")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("monthly_revenue.png")
plt.show()

# %% [markdown]
# Monthly revenue shows noticeable variation over time, with certain months outperforming others. This suggests possible seasonality or changes in demand that could be further explored for planning and forecasting.

# %%
df_products = df_products.sort_values("product_revenue")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1694056049.py in <cell line: 0>()
# ----> 1 df_products = df_products.sort_values("product_revenue")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'product_revenue'

# %%
plt.figure()
plt.barh(df_products["product_name"], df_products["product_revenue"])
plt.title("Top 10 Products by Revenue")
plt.xlabel("Revenue")
plt.ylabel("Product")
plt.tight_layout()
plt.savefig("top_ten_products.png")
plt.show()

# %% [markdown]
# This concentration suggests opportunities to prioritize inventory, marketing, and optimization efforts around these high-impact products.

# %%
df_customers = df_customers.sort_values("total_spent", ascending=False)

# %%
df_customers = pd.read_csv("/content/top_ten_customers.csv")

plt.figure()
plt.bar(df_customers["customer_name"], df_customers["total_spent"])
plt.title("Top 10 Customers by Revenue")
plt.xlabel("Customer")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("top_ten_customers.png")
plt.show()

# %% [markdown]
# A small group of customers contributes a large share of total revenue, highlighting customer concentration and potential dependency on key accounts.

# %%
df_aov = pd.read_csv("/content/avg_order_value.csv")

aov = df_aov.iloc[0, 0]
print(f"Average Order Value: {aov}")

# %% [markdown]
# The average order value reflects typical customer spending per order and provides insight into purchasing behavior and pricing effectiveness.
